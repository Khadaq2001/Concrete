# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cr_test = [0.1988,0.2042,0.1984,0.1862,0.1830,0.1878]
se_test = [0.1682,0.1707,0.1750,0.1721,0.1671,0.1545]
co_test = [0.2041,0.2084,0.2084,0.2464,0.2625,0.2680]

cr_train = [0.1887,0.1858,0.1697,0.1491,0.1273,0.1153]
se_train = [0.1408,0.1315,0.1256,0.1237,0.1163,0.1119]
co_train = [0.1884,0.1800,0.1654,0.1497,0.1280,0.1199]
x = [8,16,32,64,128,256]

# %%
plt.plot(x,cr_train,'o-',label='CellRanger')
plt.plot(x,se_train,'o-',label='Seurat')
plt.plot(x,co_train,'o-',label='Concrete')
plt.xlabel('Number of Genes')
plt.ylabel('Reconstruction loss')
plt.title('Training Loss')
plt.legend('best',labels=['CellRanger','Seurat','Concrete'])
plt.savefig('training_loss.pdf')
# Out:
# /tmp/ipykernel_122544/150157363.py:7: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend('best',labels=['CellRanger','Seurat','Concrete'])

# %%
plt.plot(x,cr_test,'o-',label='CellRanger')
plt.plot(x,se_test,'o-',label='Seurat')
plt.plot(x,co_test,'o-',label='Concrete')
plt.xlabel('Number of Genes')
plt.ylabel('Reconstruction loss')
plt.title('Test Loss')
plt.legend('best',labels=['CellRanger','Seurat','Concrete'])
plt.savefig('test_loss.pdf')
# Out:
# /tmp/ipykernel_122544/3731929837.py:7: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend('best',labels=['CellRanger','Seurat','Concrete'])
